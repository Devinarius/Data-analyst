# %% [markdown]
# ### Függyvényábrázolás

# %%
import os
ldir=os.chdir(r'C:\Users\Narshan\Python\07')
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Függvény ábrázolás

# %%
x = np.linspace(-5*np.pi, 5*np.pi, 100)
y1=np.cos(x)/x
y2=np.sin(x)/x
plt.figure(figsize=(15,15))
plt.grid(True)
plt.plot(x,y1,x,y2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Idősor ábrázolás 1->2

# %%
##1
headers = ['Month', 'Thousands of Passengers']
df= pd.read_csv('airline_passengers.csv',names=headers,delimiter=',')
df['Month']=pd.to_datetime(df1['Month'])
df['Thousands of Passengers']=pd.to_numeric(df1['Thousands of Passengers'])
df=df.dropna()
##2
fig, ax = plt.subplots(figsize=(15, 12))
half_year_locator = mdates.MonthLocator(interval=6)
ax.xaxis.set_major_locator(half_year_locator)
ax.plot(df['Month'], df['Thousands of Passengers']);
plt.title("Line chart of airline passengers")
ax.set_ylabel('Count')
ax.set_xlabel('Year')
plt.show()

# %% [markdown]
# ### DataFrame feladatok:

# %% [markdown]
# ### 1

# %%
df=pd.read_excel('Ertekesites(nagyker).xlsx','Lekérdezés1')
df.set_index('Dátum')
df1=df.groupby('Dátum')[['Bevétel','Költség','Nyereség']].sum()
df1.head(18)
# Out:
#             Bevétel   Költség  Nyereség
# Dátum
# 2015-01-02   320000  256000.0   64000.0
# 2015-01-05   320000  204800.0  115200.0
# 2015-01-13   300000  240000.0   60000.0
# 2015-01-16   300000  192000.0  108000.0
# 2015-01-23   150000  120000.0   30000.0
# 2015-01-24   280000  224000.0   56000.0
# 2015-02-01   320000  256000.0   64000.0
# 2015-02-12   300000  240000.0   60000.0
# 2015-02-13   240000  192000.0   48000.0
# 2015-02-14   450000  360000.0   90000.0
# 2015-02-22   150000  120000.0   30000.0
# 2015-02-23   280000  313600.0  -33600.0
# 2015-03-02   560000  448000.0  112000.0
# 2015-03-03   150000  138240.0   11760.0
# 2015-03-04   280000  258048.0   21952.0
# 2015-03-13   250000  200000.0   50000.0
# 2015-03-15   240000  268800.0  -28800.0
# 2015-03-16   450000  504000.0  -54000.0

# %% [markdown]
# ### 2

# %%
import numpy as np
dfE=pd.read_excel('Ertekesites(nagyker).xlsx','Lekérdezés1')
dfC=pd.crosstab([dfE['Bolt város']],[dfE['Terméknév']],margins=True,values=dfE.Nyereség,aggfunc=np.mean).round(2)
dfC=dfC.fillna(0)
## ennél biztosan lehet egyszerűben is
del dfC['Füzet']
del dfC['Ceruza']
del dfC['Gereblye']
del dfC['Kanna']
del dfC['Kapa']
del dfC['Kártya']
del dfC['Labda']
del dfC['Toll']
del dfC['Ugrókötél']
del dfC['Ásó']
dfC = dfC.drop('All')
##
plt = dfC.plot(kind="bar", stacked=False, rot=0,color="green",legend=None)

# %% [markdown]
# ### 03

# %%
dfE=pd.read_excel('Ertekesites(nagyker).xlsx','Lekérdezés1')
dfC=pd.crosstab(dfE.Vevőnév,[dfE.Kategórianév],margins=True)
##dfC.rename(columns = {'All':'Vásárlások száma'}, inplace = True)
del dfC['All']
dfC = dfC.drop('All')
plt = dfC.plot(kind="bar", stacked=True, rot=0)

# %% [markdown]
# ### 04

# %%
dfE=pd.read_excel('Ertekesites(nagyker).xlsx','Lekérdezés1')
dfE.head(13)
# Out:
#         Dátum Kategórianév Terméknév  Mennyiség  Bevétel   Költség  Nyereség  \
# 0  2015-01-02        Iroda      Toll        800   320000  256000.0   64000.0
# 1  2015-01-05        Iroda      Toll        800   320000  204800.0  115200.0
# 2  2015-01-13        Játék     Labda        600   300000  240000.0   60000.0
# 3  2015-01-16        Játék     Labda        600   300000  192000.0  108000.0
# 4  2015-01-23        Játék     Labda        300   150000  120000.0   30000.0
# 5  2015-01-24         Kert  Gereblye        400   280000  224000.0   56000.0
# 6  2015-02-01        Iroda      Toll        800   320000  256000.0   64000.0
# 7  2015-02-12        Játék     Labda        600   300000  240000.0   60000.0
# 8  2015-02-13        Iroda    Ceruza        800   240000  192000.0   48000.0
# 9  2015-02-14        Játék     Labda        900   450000  360000.0   90000.0
# 10 2015-02-22        Játék     Labda        300   150000  120000.0   30000.0
# ...

# %% [markdown]
# ### 05

# %%
dfE=pd.read_excel('Ertekesites(nagyker).xlsx','Lekérdezés1')
dfE.head(6)
# Out:
#        Dátum Kategórianév Terméknév  Mennyiség  Bevétel   Költség  Nyereség  \
# 0 2015-01-02        Iroda      Toll        800   320000  256000.0   64000.0
# 1 2015-01-05        Iroda      Toll        800   320000  204800.0  115200.0
# 2 2015-01-13        Játék     Labda        600   300000  240000.0   60000.0
# 3 2015-01-16        Játék     Labda        600   300000  192000.0  108000.0
# 4 2015-01-23        Játék     Labda        300   150000  120000.0   30000.0
# 5 2015-01-24         Kert  Gereblye        400   280000  224000.0   56000.0
#
#      Vevőnév Vevő megye Vevő város Bolt megye Bolt város Boltnév
# 0  Kovács Bt       Pest    Gödöllő      Heves       Eger  2. ABC
# 1  Kovács Bt       Pest    Gödöllő      Heves       Eger  2. ABC
# 2  Kovács Bt       Pest    Gödöllő      Heves   Gyöngyös  1. ABC
# 3  Kovács Bt       Pest    Gödöllő      Heves   Gyöngyös  1. ABC
# 4   Nagy Kft      Heves   Gyöngyös      Heves   Gyöngyös  1. ABC
# ...

# %% [markdown]
# ### 06

# %%
import numpy as np
import datetime
from datetime import date, timedelta


sdate = date(2019,9,1)   
edate = date(2019,10,1)
dft = pd.DataFrame({
    'Dátum':pd.date_range(sdate,edate-timedelta(days=1),freq='d'),    
    'D':np.random.randint(100,200,size=30),
    'E':np.random.randint(120,180,size=30)})
dft=dft.set_index('Dátum')
dft.plot()
# Out:
# <AxesSubplot:xlabel='Dátum'>
