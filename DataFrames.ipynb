# %%
import os

# %%
ldir=os.chdir(r'C:\Users\Narshan\Python\04')

# %%
import pandas as pd

# %% [markdown]
# ### 01

# %%
excel1=df=pd.read_excel('Ertekesites(nagyker).xlsx','Lekérdezés1')

# %% [markdown]
# ### 02

# %%
excel1.head(10)
# Out:
#        Dátum Kategórianév Terméknév  Mennyiség  Bevétel   Költség  Nyereség  \
# 0 2015-01-02        Iroda      Toll        800   320000  256000.0   64000.0
# 1 2015-01-05        Iroda      Toll        800   320000  204800.0  115200.0
# 2 2015-01-13        Játék     Labda        600   300000  240000.0   60000.0
# 3 2015-01-16        Játék     Labda        600   300000  192000.0  108000.0
# 4 2015-01-23        Játék     Labda        300   150000  120000.0   30000.0
# 5 2015-01-24         Kert  Gereblye        400   280000  224000.0   56000.0
# 6 2015-02-01        Iroda      Toll        800   320000  256000.0   64000.0
# 7 2015-02-12        Játék     Labda        600   300000  240000.0   60000.0
# 8 2015-02-13        Iroda    Ceruza        800   240000  192000.0   48000.0
# 9 2015-02-14        Játék     Labda        900   450000  360000.0   90000.0
#
#      Vevőnév Vevő megye Vevő város Bolt megye Bolt város Boltnév
# 0  Kovács Bt       Pest    Gödöllő      Heves       Eger  2. ABC
# ...

# %%
excel1.tail(5)
# Out:
#          Dátum Kategórianév Terméknév  Mennyiség  Bevétel   Költség  Nyereség  \
# 301 2016-12-17         Kert      Kapa       1000   800000  640000.0  160000.0
# 302 2016-12-17         Kert      Kapa       1000   800000  640000.0  160000.0
# 303 2016-12-19        Játék     Labda        900   450000  360000.0   90000.0
# 304 2016-12-20        Iroda    Ceruza       1500   450000  360000.0   90000.0
# 305 2016-12-28        Iroda      Toll        800   320000  358400.0  -38400.0
#
#        Vevőnév Vevő megye Vevő város Bolt megye Bolt város Boltnév
# 301  Kovács Bt       Pest    Gödöllő      Heves   Gyöngyös  1. ABC
# 302     Kis Bt      Heves     Hatvan      Heves   Gyöngyös  1. ABC
# 303  Kovács Bt       Pest    Gödöllő      Heves       Eger  1. ABC
# 304     Kis Bt      Heves     Hatvan      Heves   Gyöngyös  1. ABC
# 305   Nagy Kft      Heves   Gyöngyös      Heves   Gyöngyös  1. ABC

# %%
#df[index_lower_limit: index_upper_limit])
excel1[16:25]
# Out:
#         Dátum Kategórianév Terméknév  Mennyiség  Bevétel   Költség  Nyereség  \
# 16 2015-03-15        Iroda    Ceruza        800   240000  268800.0  -28800.0
# 17 2015-03-16        Játék     Labda        900   450000  504000.0  -54000.0
# 18 2015-03-23        Iroda    Ceruza       1100   330000  264000.0   66000.0
# 19 2015-03-24        Iroda      Toll        600   240000  192000.0   48000.0
# 20 2015-03-24        Iroda    Ceruza        800   240000  221184.0   18816.0
# 21 2015-04-01         Kert      Kapa        700   560000  448000.0  112000.0
# 22 2015-04-03        Játék     Labda        600   300000  240000.0   60000.0
# 23 2015-04-12        Játék    Kártya        500   250000  200000.0   50000.0
# 24 2015-04-16         Kert       Ásó        500   350000  280000.0   70000.0
#
#      Vevőnév Vevő megye Vevő város Bolt megye Bolt város Boltnév
# 16    Kis Bt      Heves     Hatvan      Heves   Gyöngyös  2. ABC
# 17    Kis Bt      Heves     Hatvan       Pest     Cegléd  2. ABC
# ...

# %% [markdown]
# ### 03

# %%
excel2=df

# %%
#excel dátum szerint van rendezve, itt nem kell rendezni a lekérdezés előtt
excel2[['Dátum','Terméknév','Bevétel']].head(20)
# Out:
#         Dátum Terméknév  Bevétel
# 0  2015-01-02      Toll   320000
# 1  2015-01-05      Toll   320000
# 2  2015-01-13     Labda   300000
# 3  2015-01-16     Labda   300000
# 4  2015-01-23     Labda   150000
# 5  2015-01-24  Gereblye   280000
# 6  2015-02-01      Toll   320000
# 7  2015-02-12     Labda   300000
# 8  2015-02-13    Ceruza   240000
# 9  2015-02-14     Labda   450000
# 10 2015-02-22     Labda   150000
# 11 2015-02-23  Gereblye   280000
# 12 2015-03-02      Kapa   560000
# 13 2015-03-03     Labda   150000
# 14 2015-03-04  Gereblye   280000
# 15 2015-03-13    Kártya   250000
# 16 2015-03-15    Ceruza   240000
# 17 2015-03-16     Labda   450000
# 18 2015-03-23    Ceruza   330000
# 19 2015-03-24      Toll   240000

# %% [markdown]
# ### 04

# %%
excel3=df
excel3.sort_values(by='Nyereség',ascending=False).head(10)
# Out:
#          Dátum Kategórianév Terméknév  Mennyiség  Bevétel   Költség  Nyereség  \
# 288 2016-11-13        Játék     Labda       2000  1000000  800000.0  200000.0
# 271 2016-10-14        Játék     Labda       2000  1000000  800000.0  200000.0
# 272 2016-10-17        Játék     Labda       2000  1000000  800000.0  200000.0
# 59  2015-07-12         Kert       Ásó       1400   980000  784000.0  196000.0
# 139 2016-02-01         Kert       Ásó       1400   980000  784000.0  196000.0
# 79  2015-08-11         Kert       Ásó       1400   980000  784000.0  196000.0
# 240 2016-08-22         Kert     Kanna       1200   960000  768000.0  192000.0
# 54  2015-06-27         Kert      Kapa       1200   960000  768000.0  192000.0
# 71  2015-07-27         Kert      Kapa       1200   960000  768000.0  192000.0
# 216 2016-07-23         Kert     Kanna       1200   960000  768000.0  192000.0
#
#        Vevőnév Vevő megye Vevő város Bolt megye Bolt város Boltnév
# ...

# %% [markdown]
# ### 05

# %%
excel4=df
excel4=excel4[['Dátum','Vevő város','Bolt város','Bevétel']].sort_values(by='Bevétel').head(5)
excel4
# Out:
#          Dátum Vevő város Bolt város  Bevétel
# 300 2016-12-09       Eger       Eger   100000
# 297 2016-12-06     Hatvan       Eger   100000
# 76  2015-08-06   Gyöngyös   Gyöngyös   120000
# 33  2015-05-11    Gödöllő   Gyöngyös   120000
# 275 2016-10-23     Hatvan     Cegléd   120000

# %%
excel4.to_csv('minbev.tsv', sep="\t",encoding='utf-8')

# %% [markdown]
# ### 06

# %%
excel5=df
excel5[excel5['Nyereség']==46464]
# Out:
#          Dátum Kategórianév Terméknév  Mennyiség  Bevétel   Költség  Nyereség  \
# 166 2016-04-16        Iroda    Ceruza        800   240000  193536.0   46464.0
# 183 2016-05-24        Iroda    Ceruza        800   240000  193536.0   46464.0
#
#        Vevőnév Vevő megye Vevő város Bolt megye Bolt város Boltnév
# 166     Kis Bt      Heves     Hatvan      Heves       Eger  2. ABC
# 183  Kovács Bt       Pest    Gödöllő      Heves     Hatvan  1. ABC

# %% [markdown]
# ### 07

# %%
excel6=df
excel6[(excel6['Bolt város']=='Hatvan') | (excel6['Bolt város']=='Eger')]
# Out:
#          Dátum Kategórianév Terméknév  Mennyiség  Bevétel   Költség  Nyereség  \
# 0   2015-01-02        Iroda      Toll        800   320000  256000.0   64000.0
# 1   2015-01-05        Iroda      Toll        800   320000  204800.0  115200.0
# 6   2015-02-01        Iroda      Toll        800   320000  256000.0   64000.0
# 12  2015-03-02         Kert      Kapa        700   560000  448000.0  112000.0
# 19  2015-03-24        Iroda      Toll        600   240000  192000.0   48000.0
# ..         ...          ...       ...        ...      ...       ...       ...
# 296 2016-12-06        Játék     Labda       1000   500000  403200.0   96800.0
# 297 2016-12-06        Iroda     Füzet        500   100000  112000.0  -12000.0
# 298 2016-12-07        Iroda     Füzet        800   160000  128000.0   32000.0
# 300 2016-12-09        Iroda     Füzet        500   100000   80000.0   20000.0
# 303 2016-12-19        Játék     Labda        900   450000  360000.0   90000.0
#
# ...

# %% [markdown]
# ### 08

# %%
excel7=df
excel7[(excel6['Bevétel']>500000)]
# Out:
#          Dátum Kategórianév Terméknév  Mennyiség  Bevétel   Költség  Nyereség  \
# 12  2015-03-02         Kert      Kapa        700   560000  448000.0  112000.0
# 21  2015-04-01         Kert      Kapa        700   560000  448000.0  112000.0
# 28  2015-04-23         Kert      Kapa        700   560000  448000.0  112000.0
# 30  2015-04-27        Iroda    Ceruza       2000   600000  480000.0  120000.0
# 43  2015-05-27        Iroda    Ceruza       2000   600000  480000.0  120000.0
# ..         ...          ...       ...        ...      ...       ...       ...
# 274 2016-10-20         Kert      Kapa        700   560000  451584.0  108416.0
# 280 2016-11-02         Kert     Kanna        700   560000  448000.0  112000.0
# 288 2016-11-13        Játék     Labda       2000  1000000  800000.0  200000.0
# 301 2016-12-17         Kert      Kapa       1000   800000  640000.0  160000.0
# 302 2016-12-17         Kert      Kapa       1000   800000  640000.0  160000.0
#
# ...

# %% [markdown]
# ## 09

# %%
excel8=df
excel8.loc[excel8['Nyereség'].idxmax()]
# Out:
# Dátum           2016-10-14 00:00:00
# Kategórianév                  Játék
# Terméknév                     Labda
# Mennyiség                      2000
# Bevétel                     1000000
# Költség                    800000.0
# Nyereség                   200000.0
# Vevőnév                    Szabó Rt
# Vevő megye                     Pest
# Vevő város                    Monor
# Bolt megye                    Heves
# Bolt város                 Gyöngyös
# Boltnév                      1. ABC
# Name: 271, dtype: object

# %% [markdown]
# ### 10

# %%
excel9=df
#excel9[['Bevétel']].mean() =kb 410 000Ft
excel9[(excel9['Bevétel'].mean()< excel9['Bevétel'])]
# Out:
#          Dátum        Ország Kategórianév Terméknév  Mennyiség  Bevétel  \
# 9   2015-02-14  Magyarország        Játék     Labda        900   450000
# 12  2015-03-02  Magyarország         Kert      Kapa        700   560000
# 17  2015-03-16  Magyarország        Játék     Labda        900   450000
# 21  2015-04-01  Magyarország         Kert      Kapa        700   560000
# 25  2015-04-16  Magyarország         Kert  Gereblye        700   490000
# ..         ...           ...          ...       ...        ...      ...
# 296 2016-12-06  Magyarország        Játék     Labda       1000   500000
# 301 2016-12-17  Magyarország         Kert      Kapa       1000   800000
# 302 2016-12-17  Magyarország         Kert      Kapa       1000   800000
# 303 2016-12-19  Magyarország        Játék     Labda        900   450000
# 304 2016-12-20  Magyarország        Iroda    Ceruza       1500   450000
#
#       Költség  Nyereség    Vevőnév Vevő megye Vevő város Bolt megye  \
# ...

# %% [markdown]
# ### 11

# %%
excel11=df #itt jöttem rá,hogy ezt teljesen feleslegesen csinálom, még jó,hogy nem az oszlop indexre hivatkoztam eddig
#excel11.insert(1,"Ország","Magyarország")
print(excel11)
# Out:
#          Dátum        Ország Kategórianév Terméknév  Mennyiség  Bevétel  \
# 0   2015-01-02  Magyarország        Iroda      Toll        800   320000
# 1   2015-01-05  Magyarország        Iroda      Toll        800   320000
# 2   2015-01-13  Magyarország        Játék     Labda        600   300000
# 3   2015-01-16  Magyarország        Játék     Labda        600   300000
# 4   2015-01-23  Magyarország        Játék     Labda        300   150000
# ..         ...           ...          ...       ...        ...      ...
# 301 2016-12-17  Magyarország         Kert      Kapa       1000   800000
# 302 2016-12-17  Magyarország         Kert      Kapa       1000   800000
# 303 2016-12-19  Magyarország        Játék     Labda        900   450000
# 304 2016-12-20  Magyarország        Iroda    Ceruza       1500   450000
# 305 2016-12-28  Magyarország        Iroda      Toll        800   320000
#
#       Költség  Nyereség    Vevőnév Vevő megye Vevő város Bolt megye  \
# ...

# %% [markdown]
# ### 12

# %%
df2=pd.read_excel('Ertekesites(nagyker).xlsx','Lekérdezés1')

# %%
df2=df2.drop(columns=['Vevő megye','Vevő város'])
print(df2)
# Out:
#          Dátum Kategórianév Terméknév  Mennyiség  Bevétel   Költség  Nyereség  \
# 0   2015-01-02        Iroda      Toll        800   320000  256000.0   64000.0
# 1   2015-01-05        Iroda      Toll        800   320000  204800.0  115200.0
# 2   2015-01-13        Játék     Labda        600   300000  240000.0   60000.0
# 3   2015-01-16        Játék     Labda        600   300000  192000.0  108000.0
# 4   2015-01-23        Játék     Labda        300   150000  120000.0   30000.0
# ..         ...          ...       ...        ...      ...       ...       ...
# 301 2016-12-17         Kert      Kapa       1000   800000  640000.0  160000.0
# 302 2016-12-17         Kert      Kapa       1000   800000  640000.0  160000.0
# 303 2016-12-19        Játék     Labda        900   450000  360000.0   90000.0
# 304 2016-12-20        Iroda    Ceruza       1500   450000  360000.0   90000.0
# 305 2016-12-28        Iroda      Toll        800   320000  358400.0  -38400.0
#
# ...

# %% [markdown]
# ### 13

# %%
df2=df2.rename(columns={"Bolt megye":"Megye"})
print(df2)
# Out:
#          Dátum Kategórianév Terméknév  Mennyiség  Bevétel   Költség  Nyereség  \
# 0   2015-01-02        Iroda      Toll        800   320000  256000.0   64000.0
# 1   2015-01-05        Iroda      Toll        800   320000  204800.0  115200.0
# 2   2015-01-13        Játék     Labda        600   300000  240000.0   60000.0
# 3   2015-01-16        Játék     Labda        600   300000  192000.0  108000.0
# 4   2015-01-23        Játék     Labda        300   150000  120000.0   30000.0
# ..         ...          ...       ...        ...      ...       ...       ...
# 301 2016-12-17         Kert      Kapa       1000   800000  640000.0  160000.0
# 302 2016-12-17         Kert      Kapa       1000   800000  640000.0  160000.0
# 303 2016-12-19        Játék     Labda        900   450000  360000.0   90000.0
# 304 2016-12-20        Iroda    Ceruza       1500   450000  360000.0   90000.0
# 305 2016-12-28        Iroda      Toll        800   320000  358400.0  -38400.0
#
# ...

# %% [markdown]
# ### 14

# %%
new_df=df2.loc[26:30,["Vevőnév"]]="Kis bt"
print(df2.loc[25:31,["Vevőnév","Bolt város"]])
# Out:
#      Vevőnév Bolt város
# 25  Nagy Kft   Gyöngyös
# 26    Kis bt   Gyöngyös
# 27    Kis bt   Gyöngyös
# 28    Kis bt       Eger
# 29    Kis bt   Gyöngyös
# 30    Kis bt     Hatvan
# 31     Monor      Monor

# %% [markdown]
# ### 15 :/

# %%
#df2=df2.set_index("Bolt város")
#df2.loc[(df2['Bolt város']=='Cegléd')]="Monor"

# %% [markdown]
# ### 16

# %%
df3=pd.read_excel('Ertekesites(nagyker).xlsx','Lekérdezés1')
df3=df3.loc[:,["Bevétel","Nyereség"]].describe()
df3=df3.loc[["std","mean"]]
df3
# Out:
#             Bevétel      Nyereség
# std   205394.201718  63144.279871
# mean  411437.908497  59011.450980

# %% [markdown]
# ### 17

# %%
df3.describe()
# Out:
#          Mennyiség         Bevétel        Költség       Nyereség
# count   306.000000      306.000000     306.000000     306.000000
# mean    849.019608   411437.908497  352426.457516   59011.450980
# std     337.710255   205394.201718  172445.436005   63144.279871
# min     300.000000   100000.000000   80000.000000  -97280.000000
# 25%     600.000000   250000.000000  225600.000000   24000.000000
# 50%     800.000000   400000.000000  327168.000000   68728.000000
# 75%    1000.000000   490000.000000  448000.000000   96000.000000
# max    2000.000000  1000000.000000  940032.000000  200000.000000

# %% [markdown]
# ### 18

# %%
df4=pd.read_excel('Ertekesites(nagyker).xlsx','Lekérdezés1')
group=df4.groupby('Bolt város')
group[['Bevétel','Nyereség']].sum()
# Out:
#              Bevétel   Nyereség
# Bolt város
# Cegléd      17450000  2424336.0
# Eger        20870000  2915312.0
# Gyöngyös    52120000  7728512.0
# Gödöllő     18990000  2113264.0
# Hatvan      16470000  2876080.0

# %% [markdown]
# ### 19

# %%
df5=pd.read_excel('Ertekesites(nagyker).xlsx','Lekérdezés1')
group=df5.groupby(['Bolt megye','Kategórianév'])
group[['Költség']].sum()
# Out:
#                             Költség
# Bolt megye Kategórianév
# Heves      Iroda         26235776.0
#            Játék         17940288.0
#            Kert          31764032.0
# Pest       Iroda          7989376.0
#            Játék          9959360.0
#            Kert          13953664.0

# %% [markdown]
# ### 20a

# %%
df6=pd.read_excel('Ertekesites(nagyker).xlsx','Lekérdezés1')
df6=df6[(df6['Bolt megye']=='Heves')]
group=df6.groupby(['Bolt megye','Terméknév'])
group.sum()
#itt kellene rendezni/kiválasztani min és maxot
# Out:
#                       Mennyiség   Bevétel     Költség   Nyereség
# Bolt megye Terméknév
# Heves      Ceruza         47900  14370000  12438144.0  1931856.0
#            Füzet          17400   3480000   3090688.0   389312.0
#            Gereblye        8900   6230000   5196800.0  1033200.0
#            Kanna           6900   5520000   4588032.0   931968.0
#            Kapa           16100  12880000  10535936.0  2344064.0
#            Kártya          8600   4300000   3821440.0   478560.0
#            Labda          29500  14750000  12386240.0  2363760.0
#            Toll           31000  12400000  10706944.0  1693056.0
#            Ugrókötél       2700   2160000   1732608.0   427392.0
#            Ásó            19100  13370000  11443264.0  1926736.0

# %% [markdown]
# ### 20b

# %%
df7=pd.read_excel('Ertekesites(nagyker).xlsx','Lekérdezés1')
df7=df7[(df7['Bolt megye']=='Heves')]
group=df6.groupby(['Bolt megye','Kategórianév'])
group[['Bevétel']].sum()
# Out:
#                           Bevétel
# Bolt megye Kategórianév
# Heves      Iroda         30250000
#            Játék         21210000
#            Kert          38000000
